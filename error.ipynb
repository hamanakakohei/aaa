# %% [markdown]
# <a href="https://colab.research.google.com/github/hamanakakohei/aaa/blob/main/error.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# condaをインストール
# !pip install -q condacolab
import condacolab
condacolab.install()

# 環境構築
# !git clone https://github.com/broadinstitute/ABC-Enhancer-Gene-Prediction
# %cd ABC-Enhancer-Gene-Prediction
# !conda env create -f ./abcenv.yml
# Out:
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:14
# 🔁 Restarting kernel...
# Cloning into 'ABC-Enhancer-Gene-Prediction'...
# remote: Enumerating objects: 8360, done.
# remote: Counting objects: 100% (146/146), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 8360 (delta 49), reused 128 (delta 44), pack-reused 8214
# Receiving objects: 100% (8360/8360), 1.50 GiB | 30.65 MiB/s, done.
# Resolving deltas: 100% (3365/3365), done.
# /content/ABC-Enhancer-Gene-Prediction
# done
# |
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
# /
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed
#
# ...
